# %% [markdown]
# <a href="https://colab.research.google.com/github/sabareeshwaran-25/VISUAL-AIDS-USING-PYTHON/blob/main/DEV_ASSIGNMENT_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/International_Report_Passengers.csv')
df.head()
# Out:
#      data_dte  Year  Month  usg_apt_id usg_apt  usg_wac  fg_apt_id fg_apt  \
# 0  05-01-2014  2014      5       14492     RDU       36      11032    CUN
# 1  06-01-2007  2007      6       13204     MCO       33      16085    YHZ
# 2  12-01-2005  2005     12       11433     DTW       43      10411    AUA
# 3  04-01-2003  2003      4       13487     MSP       63      16304    ZIH
# 4  12-01-2005  2005     12       12016     GUM        5      11138    CRK
#
#    fg_wac  airlineid carrier  carriergroup        type  Scheduled  Charter  \
# 0   148.0    19534.0      AM           0.0  Passengers        0.0    315.0
# 1   951.0    20364.0      C6           0.0  Passengers        0.0    683.0
# 2   277.0    20344.0      RD           1.0  Passengers        0.0   1010.0
# 3   148.0    20204.0      MG           1.0  Passengers        0.0    508.0
# 4   766.0    20312.0      TZ           1.0  Passengers        0.0     76.0
#
#     Total
# 0   315.0
# 1   683.0
# 2  1010.0
# 3   508.0
# 4    76.0

# %%
df1=df.head(500)
df1
# Out:
#        data_dte  Year  Month  usg_apt_id usg_apt  usg_wac  fg_apt_id fg_apt  \
# 0    05-01-2014  2014      5       14492     RDU       36      11032    CUN
# 1    06-01-2007  2007      6       13204     MCO       33      16085    YHZ
# 2    12-01-2005  2005     12       11433     DTW       43      10411    AUA
# 3    04-01-2003  2003      4       13487     MSP       63      16304    ZIH
# 4    12-01-2005  2005     12       12016     GUM        5      11138    CRK
# ..          ...   ...    ...         ...     ...      ...        ...    ...
# 495  02-01-2003  2003      2       14027     PBI       33      13165    MAN
# 496  04-01-2004  2004      4       13342     MKE       45      14312    PVR
# 497  04-01-2009  2009      4       10721     BOS       13      16217    YUL
# 498  05-01-2010  2010      5       13303     MIA       33      12180    HOG
# 499  12-01-2005  2005     12       15016     STL       64      14312    PVR
#
# ...

# %%
df1.head()
# Out:
#      data_dte  Year  Month  usg_apt_id usg_apt  usg_wac  fg_apt_id fg_apt  \
# 0  05-01-2014  2014      5       14492     RDU       36      11032    CUN
# 1  06-01-2007  2007      6       13204     MCO       33      16085    YHZ
# 2  12-01-2005  2005     12       11433     DTW       43      10411    AUA
# 3  04-01-2003  2003      4       13487     MSP       63      16304    ZIH
# 4  12-01-2005  2005     12       12016     GUM        5      11138    CRK
#
#    fg_wac  airlineid carrier  carriergroup        type  Scheduled  Charter  \
# 0   148.0    19534.0      AM           0.0  Passengers        0.0    315.0
# 1   951.0    20364.0      C6           0.0  Passengers        0.0    683.0
# 2   277.0    20344.0      RD           1.0  Passengers        0.0   1010.0
# 3   148.0    20204.0      MG           1.0  Passengers        0.0    508.0
# 4   766.0    20312.0      TZ           1.0  Passengers        0.0     76.0
#
#     Total
# 0   315.0
# 1   683.0
# 2  1010.0
# 3   508.0
# 4    76.0

# %%
df1.isnull()
# Out:
#      data_dte   Year  Month  usg_apt_id  usg_apt  usg_wac  fg_apt_id  fg_apt  \
# 0       False  False  False       False    False    False      False   False
# 1       False  False  False       False    False    False      False   False
# 2       False  False  False       False    False    False      False   False
# 3       False  False  False       False    False    False      False   False
# 4       False  False  False       False    False    False      False   False
# ..        ...    ...    ...         ...      ...      ...        ...     ...
# 495     False  False  False       False    False    False      False   False
# 496     False  False  False       False    False    False      False   False
# 497     False  False  False       False    False    False      False   False
# 498     False  False  False       False    False    False      False   False
# 499     False  False  False       False    False    False      False   False
#
# ...

# %%
df1.isnull().sum()
# Out:
# data_dte        0
# Year            0
# Month           0
# usg_apt_id      0
# usg_apt         0
# usg_wac         0
# fg_apt_id       0
# fg_apt          0
# fg_wac          0
# airlineid       0
# carrier         8
# carriergroup    0
# type            0
# Scheduled       0
# Charter         0
# Total           0
# dtype: int64

# %%
df1.describe()
# Out:
#               Year       Month    usg_apt_id     usg_wac    fg_apt_id  \
# count   500.000000  500.000000    500.000000  500.000000    500.00000
# mean   2005.372000    6.056000  13154.018000   41.496000  13472.42400
# std       2.863917    3.599831   5704.723094   24.256933   2038.55787
# min    2001.000000    1.000000  10140.000000    1.000000  10148.00000
# 25%    2003.000000    3.000000  11433.000000   23.000000  11319.75000
# 50%    2005.000000    6.000000  13204.000000   34.000000  13605.00000
# 75%    2008.000000    9.000000  14027.000000   63.000000  15174.00000
# max    2014.000000   12.000000  99999.000000   93.000000  16322.00000
#
#            fg_wac     airlineid  carriergroup  Scheduled       Charter  \
# count  500.000000    500.000000    500.000000      500.0    500.000000
# mean   421.110000  20261.964000      0.678000        0.0    829.104000
# std    302.755452    381.317612      0.467711        0.0   1442.330251
# ...

# %%
df1.tail()
# Out:
#        data_dte  Year  Month  usg_apt_id usg_apt  usg_wac  fg_apt_id fg_apt  \
# 495  02-01-2003  2003      2       14027     PBI       33      13165    MAN
# 496  04-01-2004  2004      4       13342     MKE       45      14312    PVR
# 497  04-01-2009  2009      4       10721     BOS       13      16217    YUL
# 498  05-01-2010  2010      5       13303     MIA       33      12180    HOG
# 499  12-01-2005  2005     12       15016     STL       64      14312    PVR
#
#      fg_wac  airlineid carrier  carriergroup        type  Scheduled  Charter  \
# 495   493.0    19869.0      BY           0.0  Passengers        0.0   1170.0
# 496   148.0    20423.0      U5           1.0  Passengers        0.0    397.0
# 497   941.0    19531.0      AC           0.0  Passengers        0.0    157.0
# 498   219.0    20421.0     SLQ           1.0  Passengers        0.0    343.0
# 499   148.0    20204.0      MG           1.0  Passengers        0.0   1852.0
#
#       Total
# 495  1170.0
# 496   397.0
# ...

# %%
df1.nunique()
# Out:
# data_dte        118
# Year             11
# Month            12
# usg_apt_id      119
# usg_apt         119
# usg_wac          45
# fg_apt_id       138
# fg_apt          138
# fg_wac           59
# airlineid        85
# carrier          88
# carriergroup      2
# type              1
# Scheduled         1
# Charter         359
# Total           359
# dtype: int64

# %%
x=df1.Year
y=df1.Month

# %%
plt.plot(x)

# %%
plt.scatter(x,y)

# %%
plt.hist(x)
# Out:
# (array([13175., 16972., 15137., 13795., 12778., 11698.,  9940., 12409.,
#         13262.,  1165.]),
#  array([1990. , 1992.9, 1995.8, 1998.7, 2001.6, 2004.5, 2007.4, 2010.3,
#         2013.2, 2016.1, 2019. ]),
#  <a list of 10 Patch objects>)

# %%
df1['Year'].value_counts().plot(kind="pie", autopct="%.2f")
plt.show()

# %%
df1[['airlineid']].boxplot()

# %%
plt.bar(x,y)
# Out:
# <BarContainer object of 120331 artists>

# %%
df1.plot(x='Month',y='Year',kind='area')
